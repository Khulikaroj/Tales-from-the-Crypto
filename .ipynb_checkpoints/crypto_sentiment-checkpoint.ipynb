# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient

# %matplotlib inline

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_headlines = newsapi.get_everything(q="Bitcoin",language="en",page_size=100,sort_by="relevancy")
btc_headlines["totalResults"]
# Out:
# 3638

# %%
#check sample article of Bitcoin
btc_headlines["articles"][0]
# Out:
# {'source': {'id': None, 'name': 'Gizmodo.com'},
#  'author': 'John Biggs',
#  'title': 'Crypto Traders Cut Out the Middleman, Simply Rob Victim',
#  'description': 'Two alleged crypto traders in Singapore apparently came up with a fool-proof plan: rather than convert a customer’s 365,000 Singapore dollars to bitcoin, they would simply rob the victim when he came in to do the trade.Read more...',
#  'url': 'https://gizmodo.com/crypto-traders-cut-out-the-middleman-simply-rob-victim-1845011301',
#  'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/li0fkkejdmaugm8v1fkw.jpg',
#  'publishedAt': '2020-09-10T14:28:00Z',
#  'content': 'Two alleged crypto traders in Singapore apparently came up with a fool-proof plan: rather than convert a customers 365,000 Singapore dollars to bitcoin, they would simply rob the victim when he came … [+1735 chars]'}

# %%
# Fetch the Ethereum news articles
eth_headlines = newsapi.get_everything(q="Ethereum",language="en",page_size=100,sort_by="relevancy")
eth_headlines["totalResults"]
# Out:
# 1377

# %%
#check sample article of Ethereum
eth_headlines["articles"][0]["content"]
# Out:
# "If you've interacted with cryptocurrencies in the past couple of years, there's a good chance you've used MetaMask. It's a cryptocurrency wallet in the form of a browser extension that supports Ether… [+2291 chars]"

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiments = []
for article in btc_headlines["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
        })
    except AttributeError:
        pass
btc_df = pd.DataFrame(btc_sentiments)
btc_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  Two alleged crypto traders in Singapore appare...   -0.6908     0.000
# 1  By Alexis Akwagyiram, Tom Wilson\r\n* Monthly ...    0.0000     0.000
# 2  “The COVID-19 pandemic has resulted in a mass ...    0.2732     0.063
# 3  LAGOS/LONDON (Reuters) - Four months ago, Abol...    0.0000     0.000
# 4  LAGOS/LONDON (Reuters) - Four months ago, Abol...    0.0000     0.000
#
#    negative  neutral
# 0      0.16    0.840
# 1      0.00    1.000
# 2      0.00    0.937
# 3      0.00    1.000
# 4      0.00    1.000

# %%
# Create the ethereum sentiment scores DataFrame
eth_sentiments = []
for article in eth_headlines["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
        })
    except AttributeError:
        pass
eth_df = pd.DataFrame(eth_sentiments)
eth_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  If you've interacted with cryptocurrencies in ...    0.7506     0.209
# 1  TL;DR: The Complete Stock and Cryptocurrency I...    0.0000     0.000
# 2  September\r\n18, 2020\r\n6 min read\r\nOpinion...    0.0000     0.000
# 3  LONDON (Reuters) - It sounds like a surefire b...    0.7579     0.181
# 4  NEW YORK (Reuters) - Brooklyn-based technology...    0.0000     0.000
#
#    negative  neutral
# 0       0.0    0.791
# 1       0.0    1.000
# 2       0.0    1.000
# 3       0.0    0.819
# 4       0.0    1.000

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  94.000000  94.000000  94.000000  94.000000
# mean    0.145479   0.077564   0.044128   0.878298
# std     0.477129   0.067234   0.069578   0.086050
# min    -0.865800   0.000000   0.000000   0.588000
# 25%    -0.116100   0.007000   0.000000   0.814500
# 50%     0.271400   0.085500   0.000000   0.908000
# 75%     0.507000   0.101500   0.088750   0.915000
# max     0.923100   0.326000   0.294000   1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  95.000000  95.000000  95.000000  95.000000
# mean    0.141825   0.069547   0.035442   0.895000
# std     0.402940   0.068289   0.066063   0.086984
# min    -0.910000   0.000000   0.000000   0.607000
# 25%     0.000000   0.000000   0.000000   0.842000
# 50%     0.177900   0.068000   0.000000   0.909000
# 75%     0.411700   0.103500   0.063000   0.956500
# max     0.851900   0.311000   0.347000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin has higher average positive score (0.077564>0.068011).
#
# Q: Which coin had the highest compound score?
#
# A: Maximum of comcpound score is greater in Bitcoin(0.923100>0.851900).
#
# Q. Which coin had the highest positive score?
#
# A: Maximum of positive score is greater in Bitcoin(0.32600>0.311000).

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
lemmatizer = WordNetLemmatizer()
def tokenizer(text):
    """Tokenizes text."""
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    return tokens

# %%
btc_sentiments = []
btc_tokens_corpus = []
for article in btc_headlines["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        article_tokens = tokenizer(text)
        
        btc_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu,
            "tokens": article_tokens
        })
        btc_tokens_corpus.append(article_tokens)
        
    except AttributeError:
        pass
btc_df = pd.DataFrame(btc_sentiments)
btc_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  Two alleged crypto traders in Singapore appare...   -0.6908     0.000
# 1  By Alexis Akwagyiram, Tom Wilson\r\n* Monthly ...    0.0000     0.000
# 2  “The COVID-19 pandemic has resulted in a mass ...    0.2732     0.063
# 3  LAGOS/LONDON (Reuters) - Four months ago, Abol...    0.0000     0.000
# 4  LAGOS/LONDON (Reuters) - Four months ago, Abol...    0.0000     0.000
#
#    negative  neutral                                             tokens
# 0      0.16    0.840  [two, alleged, crypto, trader, singapore, appa...
# 1      0.00    1.000  [alexis, akwagyiram, tom, wilson, monthly, cry...
# 2      0.00    0.937  [covid, pandemic, ha, resulted, mass, shift, w...
# 3      0.00    1.000  [lagoslondon, reuters, four, month, ago, abola...
# 4      0.00    1.000  [lagoslondon, reuters, four, month, ago, abola...

# %%
# Create a new tokens column for bitcoin
eth_sentiments = []
eth_tokens_corpus = []
for article in eth_headlines["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        article_tokens = tokenizer(text)
        
        btc_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu,
            "tokens": article_tokens
        })
        eth_tokens_corpus.append(article_tokens)
    except AttributeError:
        pass
eth_df = pd.DataFrame(btc_sentiments)
eth_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  Two alleged crypto traders in Singapore appare...   -0.6908     0.000
# 1  By Alexis Akwagyiram, Tom Wilson\r\n* Monthly ...    0.0000     0.000
# 2  “The COVID-19 pandemic has resulted in a mass ...    0.2732     0.063
# 3  LAGOS/LONDON (Reuters) - Four months ago, Abol...    0.0000     0.000
# 4  LAGOS/LONDON (Reuters) - Four months ago, Abol...    0.0000     0.000
#
#    negative  neutral                                             tokens
# 0      0.16    0.840  [two, alleged, crypto, trader, singapore, appa...
# 1      0.00    1.000  [alexis, akwagyiram, tom, wilson, monthly, cry...
# 2      0.00    0.937  [covid, pandemic, ha, resulted, mass, shift, w...
# 3      0.00    1.000  [lagoslondon, reuters, four, month, ago, abola...
# 4      0.00    1.000  [lagoslondon, reuters, four, month, ago, abola...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
btc_bigram_counts = ngrams(tokenizer(btc_df.text.str.cat()), n=2)
Counter(btc_bigram_counts).most_common(20)
# Out:
# [(('satoshi', 'nakaboto'), 42),
#  (('charsour', 'robot'), 21),
#  (('robot', 'colleague'), 21),
#  (('colleague', 'satoshi'), 21),
#  (('nakaboto', 'writes'), 21),
#  (('writes', 'bitcoin'), 21),
#  (('every', 'fucking'), 21),
#  (('fucking', 'daywelcome'), 21),
#  (('daywelcome', 'another'), 21),
#  (('another', 'edition'), 21),
#  (('edition', 'bitcoin'), 21),
#  (('bitcoin', 'today'), 21),
#  (('today', 'satoshi'), 21),
#  (('nakaboto', 'tell'), 21),
#  (('tell', 'whats'), 21),
#  (('whats', 'going'), 21),
#  (('going', 'bitcoin'), 21),
#  (('bitcoin', 'charsour'), 19),
#  (('bitcoin', 'btc'), 18),
#  (('btc', 'every'), 18)]

# %%
# Generate the Bitcoin N-grams where N=2
eth_bigram_counts = ngrams(tokenizer(eth_df.text.str.cat()), n=2)
Counter(eth_bigram_counts).most_common(20)
# Out:
# [(('satoshi', 'nakaboto'), 44),
#  (('charsour', 'robot'), 22),
#  (('robot', 'colleague'), 22),
#  (('colleague', 'satoshi'), 22),
#  (('nakaboto', 'writes'), 22),
#  (('writes', 'bitcoin'), 22),
#  (('every', 'fucking'), 22),
#  (('fucking', 'daywelcome'), 22),
#  (('daywelcome', 'another'), 22),
#  (('another', 'edition'), 22),
#  (('edition', 'bitcoin'), 22),
#  (('bitcoin', 'today'), 22),
#  (('today', 'satoshi'), 22),
#  (('nakaboto', 'tell'), 22),
#  (('tell', 'whats'), 22),
#  (('whats', 'going'), 22),
#  (('going', 'bitcoin'), 22),
#  (('bitcoin', 'btc'), 21),
#  (('btc', 'every'), 19),
#  (('bitcoin', 'charsour'), 19)]

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
token_count(tokenizer(btc_df.text.str.cat()))
# Out:
# [('bitcoin', 86),
#  ('satoshi', 42),
#  ('nakaboto', 42),
#  ('every', 23),
#  ('going', 23),
#  ('another', 22),
#  ('edition', 22),
#  ('ha', 21),
#  ('charsour', 21),
#  ('robot', 21)]

# %%
# Get the top 10 words for Ethereum
token_count(tokenizer(eth_df.text.str.cat()))
# Out:
# [('bitcoin', 104),
#  ('ethereum', 58),
#  ('ha', 50),
#  ('satoshi', 44),
#  ('nakaboto', 44),
#  ('btc', 30),
#  ('cryptocurrency', 29),
#  ('today', 26),
#  ('blockchain', 26),
#  ('another', 25)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
big_string = ' '.join(tokenizer(btc_df.text.str.cat()))
wc = WordCloud().generate(big_string)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
big_string = ' '.join(tokenizer(eth_df.text.str.cat()))
wc = WordCloud().generate(big_string)
plt.imshow(wc)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
btc_articles = ' '.join(tokenizer(btc_df.text.str.cat()))

# %%
# Run the NER processor on all of the text
doc = nlp(btc_articles)

# Add a title to the document
# I'm not sure what to do at this stage

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  alleged crypto trader
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     singapore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  apparently came foolproof plan rather convert customer
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     singapore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dollar bitcoin would simply rob victim came
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     charsby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  alexis
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     akwagyiram tom wilson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  crypto transfer
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  rise
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  much activity nigeria
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     south africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kenya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  driven small business migrant charsthe covid pandemic ha resulted mass shift working home resulting increased use corporate vpn elimination inperson verification partially explain succes charslagoslondon
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four month ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  abolaji odunjo made fundamental change business selling mobile phone bustling street market lagos started paying supplier bitco charslagoslondon
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four month ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  abolaji odunjo made fundamental change business selling mobile phone bustling street market lagos started paying supplier bitco charsour robot colleague
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     satoshi nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  writes
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  btc every fucking daywelcome another edition
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  satoshi nakaboto tell whats going bitcoin charsour robot colleague satoshi nakaboto writes
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  btc every fucking daywelcome another edition
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  satoshi nakaboto tell whats going bitcoin charsour robot colleague satoshi nakaboto write

# %%
# List all Entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# two CARDINAL
# singapore GPE
# singapore GPE
# charsby PERSON
# akwagyiram tom wilson PERSON
# monthly DATE
# africa LOC
# year DATE
# south africa GPE
# kenya GPE
# reuters ORG
# four month ago DATE
# reuters ORG
# four month ago DATE
# satoshi nakaboto ORG
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# today DATE
# today DATE
# today DATE
# bitcoin charsftx cryptocurrency exchange ORG
# app ORG
# million CARDINAL
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# charsseptember min readopinions ORG
# five year ago DATE
# charsan outspoken bitcoin ORG
# two CARDINAL
# joe PERSON
# unus PERSON
# leo leo PERSON
# fiat ORG
# charsthe canton bill PRODUCT
# crypto valley LOC
# swiss NORP
# bitcoin GPE
# exuber NORP
# joe sullivan PERSON
# us GPE
# united states GPE
# district court ORG
# northern district LOC
# thursday DATE
# russian NORP
# reuters kazakhstan ORG
# bagdat mussin PERSON
# wedn PERSON
# lincolnshire GPE
# two CARDINAL
# three CARDINAL
# two CARDINAL
# tesco ORG
# storesnigel wright PERSON
# charsby reuters PERSON
# digital ORG
# ta qali charsby PERSON
# silhouette PRODUCT
# reutersdado ruvicillust charsbangkok reuters hospitals company ORG
# thailand GPE
# thursday DATE
# gove ORG
# bitcoin GPE
# around million CARDINAL
# seventh ORDINAL
# charswashington reuters PERSON
# thursday DATE
# thursday DATE
# north korean NORP
# million dollar MONEY
# two CARDINAL
# thursday DATE
# north korean NORP
# million dollar MONEY
# two CARDINAL
# bitcoin scam PERSON
# july DATE
# three CARDINAL
# uk la charssjoerd knibbeler ORG
# yearold massachusetts ORG
# twitter hackback july authority ORG
# yearold graham clark PERSON
# reuters journalist ORG
# charsin addition obstruction ORG
# sullivan PERSON
# eight year DATE
# one CARDINAL
# sr acct PERSON
# michael scott PERSON
# five CARDINAL
# one CARDINAL
# past year DATE
# one CARDINAL
# one CARDINAL
# million CARDINAL
# deloitte kpmg fidelity ORG
# moderatorhas ORG
# year DATE
# depa charsin PERSON
# hour morning TIME
# john wick PERSON
# overa twitter PERSON
# indian NORP
# narendra modis PERSON
# charslondon reuters ORG
# g charsif PERSON
# past year DATE
# one CARDINAL
# sunday DATE
# evening TIME
# softbank cool billionin age ORG
# nine zero CARDINAL
# two CARDINAL
# bitcoin bug PERSON
# langcnetthe department ORG
# thursday DATE
# tesla ORDINAL
# nevada GPE
# russian NORP
# russian NORP
# accuse charsmy PERSON
# youtube hour TIME
# displ PERSON
# newsullia slovenian NORP
# two year DATE
# us GPE
# donald trump PERSON
# wednesday DATE
# american tire automotive gear company ORG
# bitcoin GPE
# charsbitcoin GPE
# bitcoin GPE
# bitcoin GPE
# bitcoin GPE
# charsuber DATE
# joseph sullivan PERSON
# usthe yearold PERSON
# february DATE
# germany GPE
# week losing hour TIME
# august DATE
# july DATE
# tra charslast month DATE
# bitcoin GPE
# bitcoin GPE
# consolidatin charsbitcoin FAC
# ten year DATE
# second ORDINAL
# one CARDINAL
# last hour TIME
# morning TIME
# thursday DATE
# north korean NORP
# million dollar MONEY
# two CARDINAL
# united states GPE
# american multinational financial service corporation ORG
# alex taisopa PERSON
# charsbitcoin GPE
# recent month DATE
# march DATE
# million CARDINAL
# charsbitcoin GPE
# bitcoin GPE
# million CARDINAL
# americans NORP
# earlier year DATE
# democrats NORP
# republicans NORP
# second ORDINAL
# one CARDINAL
# one CARDINAL
# million million CARDINAL

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
eth_articles = ' '.join(tokenizer(eth_df.text.str.cat()))

# %%
# Run the NER processor on all of the text
doc = nlp(eth_articles)

# Add a title to the document
# I'm not sure what to do at this stage

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  alleged crypto trader
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     singapore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  apparently came foolproof plan rather convert customer
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     singapore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dollar bitcoin would simply rob victim came
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     charsby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  alexis
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     akwagyiram tom wilson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  crypto transfer
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  rise
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  much activity nigeria
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     south africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kenya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  driven small business migrant charsthe covid pandemic ha resulted mass shift working home resulting increased use corporate vpn elimination inperson verification partially explain succes charslagoslondon
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four month ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  abolaji odunjo made fundamental change business selling mobile phone bustling street market lagos started paying supplier bitco charslagoslondon
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four month ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  abolaji odunjo made fundamental change business selling mobile phone bustling street market lagos started paying supplier bitco charsour robot colleague
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     satoshi nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  writes
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  btc every fucking daywelcome another edition
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  satoshi nakaboto tell whats going bitcoin charsour robot colleague satoshi nakaboto writes
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  btc every fucking daywelcome another edition
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  satoshi nakaboto tell whats going bitcoin charsour robot colleague satoshi nakaboto write

# %%
# List all Entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# two CARDINAL
# singapore GPE
# singapore GPE
# charsby PERSON
# akwagyiram tom wilson PERSON
# monthly DATE
# africa LOC
# year DATE
# south africa GPE
# kenya GPE
# reuters ORG
# four month ago DATE
# reuters ORG
# four month ago DATE
# satoshi nakaboto ORG
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# today DATE
# today DATE
# today DATE
# bitcoin charsftx cryptocurrency exchange ORG
# app ORG
# million CARDINAL
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# bitcoin GPE
# bitcoin GPE
# today DATE
# charsseptember min readopinions ORG
# five year ago DATE
# charsan outspoken bitcoin ORG
# two CARDINAL
# joe PERSON
# unus PERSON
# leo leo PERSON
# fiat ORG
# charsthe canton bill PRODUCT
# crypto valley LOC
# swiss NORP
# bitcoin GPE
# exuber NORP
# joe sullivan PERSON
# us GPE
# united states GPE
# district court ORG
# northern district LOC
# thursday DATE
# russian NORP
# reuters kazakhstan ORG
# bagdat mussin PERSON
# wedn PERSON
# lincolnshire GPE
# two CARDINAL
# three CARDINAL
# two CARDINAL
# tesco ORG
# storesnigel wright PERSON
# charsby reuters PERSON
# digital ORG
# ta qali charsby PERSON
# silhouette PRODUCT
# reutersdado ruvicillust charsbangkok reuters hospitals company ORG
# thailand GPE
# thursday DATE
# gove ORG
# bitcoin GPE
# around million CARDINAL
# seventh ORDINAL
# charswashington reuters PERSON
# thursday DATE
# thursday DATE
# north korean NORP
# million dollar MONEY
# two CARDINAL
# thursday DATE
# north korean NORP
# million dollar MONEY
# two CARDINAL
# bitcoin scam PERSON
# july DATE
# three CARDINAL
# uk la charssjoerd knibbeler ORG
# yearold massachusetts ORG
# twitter hackback july authority ORG
# yearold graham clark PERSON
# reuters journalist ORG
# charsin addition obstruction ORG
# sullivan PERSON
# eight year DATE
# one CARDINAL
# sr acct PERSON
# michael scott PERSON
# five CARDINAL
# one CARDINAL
# past year DATE
# one CARDINAL
# one CARDINAL
# million CARDINAL
# deloitte kpmg fidelity ORG
# moderatorhas ORG
# year DATE
# depa charsin PERSON
# hour morning TIME
# john wick PERSON
# overa twitter PERSON
# indian NORP
# narendra modis PERSON
# charslondon reuters ORG
# g charsif PERSON
# past year DATE
# one CARDINAL
# sunday DATE
# evening TIME
# softbank cool billionin age ORG
# nine zero CARDINAL
# two CARDINAL
# bitcoin bug PERSON
# langcnetthe department ORG
# thursday DATE
# tesla ORDINAL
# nevada GPE
# russian NORP
# russian NORP
# accuse charsmy PERSON
# youtube hour TIME
# displ PERSON
# newsullia slovenian NORP
# two year DATE
# us GPE
# donald trump PERSON
# wednesday DATE
# american tire automotive gear company ORG
# bitcoin GPE
# charsbitcoin GPE
# bitcoin GPE
# bitcoin GPE
# bitcoin GPE
# charsuber DATE
# joseph sullivan PERSON
# usthe yearold PERSON
# february DATE
# germany GPE
# week losing hour TIME
# august DATE
# july DATE
# tra charslast month DATE
# bitcoin GPE
# bitcoin GPE
# consolidatin charsbitcoin FAC
# ten year DATE
# second ORDINAL
# one CARDINAL
# last hour TIME
# morning TIME
# thursday DATE
# north korean NORP
# million dollar MONEY
# two CARDINAL
# united states GPE
# american multinational financial service corporation ORG
# alex taisopa PERSON
# charsbitcoin GPE
# recent month DATE
# march DATE
# million CARDINAL
# charsbitcoin GPE
# bitcoin GPE
# million CARDINAL
# americans NORP
# earlier year DATE
# democrats NORP
# republicans NORP
# second ORDINAL
# one CARDINAL
# one CARDINAL
# million million CARDINAL
# past couple year DATE
# charsseptember min readopinions ORG
# five year ago DATE
# charslondon reuters ORG
# jpmorgan chase amp cos jpmn ORG
# marquee NORP
# tuesday DATE
# dea charsan outspoken bitcoin PERSON
# two CARDINAL
# joe PERSON
# unus PERSON
# leo leo PERSON
# satoshi nakaboto PERSON
# bitcoin GPE
# bitcoin GPE
# today DATE
# second ORDINAL
# one CARDINAL
# last hour TIME
# million CARDINAL
# deloitte kpmg fidelity ORG
# uni ORG
# september DATE
# getty imagesuniswap PERSON
# charspoland photo illustration ethereum ORG
# getty imagessopa PERSON
# twenty dollar MONEY
# bitcoin GPE
# bitcoin GPE
# charsthe securities exchange commission ORG
# charsseptember min readopinions ORG
# past month DATE
# charsover billion MONEY
# bitcoin GPE
# bitcoin btc GPE
# thursday DATE
# january DATE
# microsoft consensysamd PERSON
# us GPE
# christine kim PERSON
# danny ryan liz steininger PERSON
# digital cryptocurrency exchangeeuropean cryptocurrency exchange ORG
# superio charsdefi PERSON
# monday DATE
# new alltime GPE
# second ORDINAL
# three week DATE
# onchain data ORG
# coindeskullias ORG
# tuesday DATE
# thursday DATE
# previous hour TIME
# christine kim PERSON
# ben edgington vijay michalik PERSON
# today DATE
# two CARDINAL
# russian NORP
# nearly million CARDINAL
# implode ORG
# landmark ipo billion CARDINAL
# tron ethereum ORG
# wednesday DATE
# micr charsquorum ORG
# megabank jpmorgan chase PERSON
# consensys brooklyn ORG
# jpmorgan PERSON
# un ORG
# billion CARDINAL
# charswhen news ORG
# last month DATE
# us GPE
# occ ORG
# bitcoin GPE
# wednesday DATE
# previous hour TIME
# bitcoin GPE
# noon TIME
# chinas food safety watchdog ORG
# charsthe takeawayulliunder development lnpbp standards association ORG
# second ORDINAL
# year DATE
# us GPE
# million CARDINAL
# uniswaps uni PRODUCT
# thursday DATE
# zero CARDINAL
# past week DATE
# emfarsis PERSON
# january DATE
# two CARDINAL
# last week DATE
# algorand us dollar coin usdc symbol ORG
# three CARDINAL
# month DATE
# past month DATE
# may june DATE
# today DATE
# house snowfork ORG
# blog PERSON
# coindeskarbol GPE
# token x exchange ORG
# charsan ethereum smart ORG
# two week DATE
# inx ltd ORG
# telco giant ORG
# grant web foundation ORG
# thursday DATE
# marketsa GPE
# stefan george gnosis PERSON
# coindesk PERSON
# one CARDINAL
# token uni wa PRODUCT
# wednesday night TIME
# past hour TIME
# charsbloomberg news ORG
# mathew leisings PERSON
# first ORDINAL
# thursday DATE
# million CARDINAL
# one dollar MONEY
# new alltime GPE
# tuesday DATE
# approachingdanny ryan core developer ethereum PERSON
# today DATE
# saturday evening TIME
# third attack month DATE
# first ORDINAL
# platfo charslife PERSON
# bitcoin GPE
# weekly DATE
# march DATE
# ren token renvm defi PRODUCT
# past week DATE
# tuesday DATE
# monday DATE
# early morning TIME
# monday DATE
# sunday DATE
# start day eos DATE
# early morning TIME
# dozen CARDINAL
# charsmongolian authority ORG
# one CARDINAL
# next monday DATE
# wednesday DATE
# charsmongolian NORP
# medalla testnet PERSON
# last month DATE
# one CARDINAL
# monday DATE
# blog post eth ORG
# today DATE
# billion CARDINAL
# blockchaintether cto paolo PERSON
# ethvm ORG
# conduc ORG
# march DATE
